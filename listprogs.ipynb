# %%
#1
nums=[]
for i in range (5):
    num=int(input("enter number: "))
    nums.append(num)

print(nums)
index=int(input("enter index of item to be removed:"))
nums.pop(index)
print(nums)
# Out:
# enter number:  2
# enter number:  3
# enter number:  4
# enter number:  5
# enter number:  6
# [2, 3, 4, 5, 6]
# enter index of item to be removed: 2
# [2, 3, 5, 6]

# %%
#2
nums = [10, 20, 30, 40, 50]
newnum = int(input("enter number to be appended: "))
nums.append(newnum)
print(nums)
# Out:
# enter number to be appended:  30
# [10, 20, 30, 40, 50, 30]

# %%
#3
nums = [10, 20, 30, 40, 50]
print(nums)
nums.reverse()
print(nums)
# Out:
# [10, 20, 30, 40, 50]
# [50, 40, 30, 20, 10]
